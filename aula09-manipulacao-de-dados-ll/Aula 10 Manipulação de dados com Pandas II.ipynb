# %% [markdown]
# # Manipulação de dados com Pandas II
#
# ## Agregando Dados

# %% [markdown]
# Vamos utilizar o mesmo dataset da aula anterior de introdução ao Pandas, analisando também os preços dos produtos.

# %%
import pandas as pd

df = pd.read_csv('orders.csv')
df.head()
# Out:
#       id first_name    last_name                      email     shoe_type  \
# 0  41874       Kyle         Peck       KylePeck71@gmail.com  ballet flats
# 1  31349  Elizabeth    Velazquez   EVelazquez1971@gmail.com         boots
# 2  43416      Keith     Saunders           KS4047@gmail.com       sandals
# 3  56054       Ryan      Sweeney  RyanSweeney14@outlook.com       sandals
# 4  77402      Donna  Blankenship           DB3807@gmail.com     stilettos
#
#   shoe_material shoe_color  price
# 0  faux-leather      black  385.0
# 1        fabric      brown  388.0
# 2       leather       navy  346.0
# 3        fabric      brown  344.0
# 4        fabric      brown  289.0

# %% [markdown]
# São funções de agregação básicas: contagem, valores máximo e mínimo, média, desvio padrão e variância dos valores.

# %%
print("count: ", df['price'].count())
print("max: ", df['price'].max())
print("min: ", df['price'].min())
print("média: ", df['price'].mean())
print("std: ", df['price'].std())
print("var: ", df['price'].var())
# Out:
# count:  98
# max:  493.0
# min:  91.0
# média:  289.1326530612245
# std:  110.95477278241789
# var:  12310.961603197982

# %% [markdown]
# São estatísticas básicas a mediana (2º quartil) e quartis:

# %%
print("mediana: ", df['price'].median())
print("quantile: ", df['price'].quantile(0))
print("quantile: ", df['price'].quantile(0.25))
print("quantile: ", df['price'].quantile(0.5))
print("quantile: ", df['price'].quantile(0.75))
print("quantile: ", df['price'].quantile(1))
# Out:
# mediana:  285.5
# quantile:  91.0
# quantile:  205.5
# quantile:  285.5
# quantile:  373.5
# quantile:  493.0

# %%
describe = df.describe().round(2)
describe
# Out:
#              id   price
# count     99.00   98.00
# mean   53195.33  289.13
# std    25421.25  110.95
# min    10204.00   91.00
# 25%    31563.00  205.50
# 50%    54049.00  285.50
# 75%    75457.50  373.50
# max    97943.00  493.00

# %% [markdown]
# Para as colunas que não possuem valores numéricos, é possível estabelecer algumas verificações, como quantos e quais valores únicos cada uma delas possuem:

# %%
print(df.shoe_material.unique())
print(df.shoe_material.nunique())
# Out:
# ['faux-leather' 'fabric' 'leather']
# 3

# %% [markdown]
# Para agrupar informações importantes, como, por exemplo, o preço mais alto por tipo de calçado, podemos utilizar a função `groupby`:

# %%
pricey_shoes = df.groupby('shoe_type').price.max()
pricey_shoes
# Out:
#                  id first_name   last_name                          email  \
# shoe_type
# ballet flats  93774   Victoria        Vega  VictoriaHiggins66@hotmail.com
# boots         94489     Walter   Velazquez    Walter.Cunningham@gmail.com
# clogs         97943    William  Valenzuela    WilliamCalderon79@gmail.com
# sandals       83961    Zachary     Watkins      Zachary.Gregory@gmail.com
# stilettos     97228      Wayne       Small           WSmall1987@gmail.com
# wedges        97148     Willie   Whitfield               WS5572@gmail.com
#
#              shoe_material shoe_color  price
# shoe_type
# ballet flats       leather      white  481.0
# boots              leather      white  478.0
# clogs              leather      white  493.0
# sandals            leather      white  456.0
# stilettos          leather      white  487.0
# wedges             leather      white  461.0

# %% [markdown]
# Para transformar o resultado do agrupamento em um novo dataframe, basta acrescentar `reset_index()` no fim:

# %%
pricey_shoes = df.groupby('shoe_type').price.max().reset_index()
pricey_shoes
# Out:
#       shoe_type  price
# 0  ballet flats  481.0
# 1         boots  478.0
# 2         clogs  493.0
# 3       sandals  456.0
# 4     stilettos  487.0
# 5        wedges  461.0

# %% [markdown]
# E assim podemos renomear as colunas, se for necessário:

# %%
pricey_shoes = pricey_shoes.rename(columns={'price': 'max_price'})
pricey_shoes
# Out:
#       shoe_type  max_price
# 0  ballet flats      481.0
# 1         boots      478.0
# 2         clogs      493.0
# 3       sandals      456.0
# 4     stilettos      487.0
# 5        wedges      461.0

# %%
pricey_shoes_2 = df.groupby(['shoe_type', 'shoe_color']).price.max().reset_index().rename(columns={'price': 'max_price'})
pricey_shoes_2
# Out:
#        shoe_type shoe_color  max_price
# 0   ballet flats      black      385.0
# 1   ballet flats      brown      481.0
# 2   ballet flats        red      331.0
# 3   ballet flats      white      308.0
# 4          boots      black      171.0
# 5          boots      brown      388.0
# 6          boots       navy      478.0
# 7          boots        red      435.0
# 8          boots      white      339.0
# 9          clogs      black      451.0
# 10         clogs      brown      323.0
# 11         clogs       navy      493.0
# 12         clogs        red      439.0
# 13         clogs      white      324.0
# 14       sandals      black        NaN
# 15       sandals      brown      344.0
# 16       sandals       navy      346.0
# 17       sandals        red      409.0
# 18       sandals      white      456.0
# 19     stilettos      black      451.0
# 20     stilettos      brown      481.0
# 21     stilettos       navy      487.0
# 22     stilettos        red      474.0
# 23     stilettos      white      342.0
# 24        wedges      black      289.0
# 25        wedges      brown      429.0
# 26        wedges       navy      406.0
# 27        wedges        red      461.0
# 28        wedges      white      180.0

# %% [markdown]
# Para realizar o agrupamento com mais de uma coluna, basta passar uma lista como parâmetro da função `groupby`:

# %%
pricey_shoes_3 = df.groupby(['shoe_type', 'shoe_color']).price.agg(['max', 'min']).reset_index().rename(columns={'max': 'max_price', 'min': 'min_price'})
pricey_shoes_3
# Out:
#        shoe_type shoe_color  max_price  min_price
# 0   ballet flats      black      385.0      226.0
# 1   ballet flats      brown      481.0       91.0
# 2   ballet flats        red      331.0      187.0
# 3   ballet flats      white      308.0      106.0
# 4          boots      black      171.0      100.0
# 5          boots      brown      388.0      176.0
# 6          boots       navy      478.0      205.0
# 7          boots        red      435.0      247.0
# 8          boots      white      339.0      193.0
# 9          clogs      black      451.0      221.0
# 10         clogs      brown      323.0       93.0
# 11         clogs       navy      493.0      493.0
# 12         clogs        red      439.0       95.0
# 13         clogs      white      324.0      324.0
# 14       sandals      black        NaN        NaN
# 15       sandals      brown      344.0      113.0
# 16       sandals       navy      346.0      122.0
# 17       sandals        red      409.0      185.0
# 18       sandals      white      456.0      236.0
# 19     stilettos      black      451.0      285.0
# 20     stilettos      brown      481.0      289.0
# 21     stilettos       navy      487.0      167.0
# 22     stilettos        red      474.0      430.0
# 23     stilettos      white      342.0      241.0
# 24        wedges      black      289.0      115.0
# 25        wedges      brown      429.0      141.0
# 26        wedges       navy      406.0      195.0
# 27        wedges        red      461.0      253.0
# 28        wedges      white      180.0      161.0

# %% [markdown]
# Para melhor compreensão, analise outro exemplo: A Biblioteca Municipal tem várias filiais espalhadas pela cidade. Em cada uma delas são  coletados todos os dados de retirada de livros em um DataFrame chamado `checkouts`.
#
# O DataFrame contém as colunas `location`, `date` e `book_title`. Se quisermos comparar o número total de livros retirados em cada filial, qual código poderíamos usar?
#
# ```
# checkouts.groupby(['location']).book_title.count().reset_index()
# ```

# %% [markdown]
# No exemplo anterior, vimos que muitos dos dados se repetiram. Isso acontece porque fizemos o agrupamento por mais de uma coluna, o que pode ser resolvido estabelecendo um tabela pivô:
#
# ```
# df.pivot(columns='ColumnToPivot',
#          index='ColumnToBeRows',
#          values='ColumnToBeValues')
# ```

# %%
shoe_max_pivot = pricey_shoes_3.pivot(columns='shoe_color', index='shoe_type', values='max_price').reset_index()
shoe_max_pivot
# Out:
# shoe_color     shoe_type  black  brown   navy    red  white
# 0           ballet flats  385.0  481.0    NaN  331.0  308.0
# 1                  boots  171.0  388.0  478.0  435.0  339.0
# 2                  clogs  451.0  323.0  493.0  439.0  324.0
# 3                sandals    NaN  344.0  346.0  409.0  456.0
# 4              stilettos  451.0  481.0  487.0  474.0  342.0
# 5                 wedges  289.0  429.0  406.0  461.0  180.0

# %% [markdown]
# É possível mesclar o cálculo de estatísticas com o agrupamento dos dados. Por exemplo, para calcular o percentil de 25% (1º quartil) do preço com base no agrupamento por cor do calçado, teremos os sapatos mais baratos assim:

# %%
import numpy as np

cheap_shoes = df.groupby('shoe_color').price.apply(lambda x: np.percentile(x, 25)).reset_index()

cheap_shoes
# Out:
#   shoe_color  price
# 0      black    NaN
# 1      brown  193.5
# 2       navy  205.5
# 3        red  250.0
# 4      white  196.0

# %% [markdown]
# ## Ordenando Dados

# %%
df.sort_values(['price', 'shoe_type'], ascending=[False, True])
# Out:
#        id first_name  last_name                       email     shoe_type  \
# 64  13553      Aaron     Hanson            AH3867@gmail.com         clogs
# 38  87313      Wayne      Small        WSmall1987@gmail.com     stilettos
# 18  35693   Margaret      Tyler        MTyler1974@gmail.com  ballet flats
# 34  85959      Julie       Rosa       JRosa1990@outlook.com     stilettos
# 39  18507      Donna       Clay          DC4155@hotmail.com         boots
# ..    ...        ...        ...                         ...           ...
# 36  24421      Megan     Rhodes            MR1115@gmail.com         boots
# 84  67253      Amber  Daugherty  AmberDaugherty60@gmail.com         clogs
# 86  39447     Denise    Mendoza          DM2227@outlook.com         clogs
# 12  39587     Dennis       Vega       Dennis.Vega@gmail.com  ballet flats
# 98  26210    Marilyn      Finch    MarilynFinch92@gmail.com       sandals
#
#    shoe_material shoe_color  price
# 64  faux-leather       navy  493.0
# 38  faux-leather       navy  487.0
# 18        fabric      brown  481.0
# 34       leather      brown  481.0
# 39        fabric       navy  478.0
# ..           ...        ...    ...
# 36        fabric      black  100.0
# 84  faux-leather        red   95.0
# 86  faux-leather      brown   93.0
# 12  faux-leather      brown   91.0
# 98       leather      black    NaN
#
# [99 rows x 8 columns]

# %% [markdown]
# ## Concatenando Dados

# %%
tabela_1 = pd.read_csv('tabela1.csv')
tabela_1
# Out:
#     nome  telefone   carros
# 0   João    121212     azul
# 1   João    343434    preto
# 2  Pedro    565656    verde
# 3   Caio    787878  amarelo

# %%
tabela_2 = pd.read_csv('tabela2.csv')
tabela_2
# Out:
#       nome  irmãos
# 0     João       1
# 1  Marcelo       3
# 2   Thiago       2
# 3     Caio       2

# %%
tabela_3 = pd.read_csv('tabela3.csv')
tabela_3
# Out:
#     nome  telefone    carros
# 0   João    121212    BRANCO
# 1   João    343434     PRATA
# 2  Pedro    565656     PRATA
# 3   Caio    787878  VERMELHO

# %% [markdown]
# Veremos como este método se comporta em dois cenários:
#
# ### Cenário 1
#
# Vejamos como a método se comporta no caso de tabelas com as mesmas colunas. O método gera uma tabela com todas as combinações de colunas.

# %%
pd.concat([tabela_1, tabela_3])
# Out:
#     nome  telefone    carros
# 0   João    121212      azul
# 1   João    343434     preto
# 2  Pedro    565656     verde
# 3   Caio    787878   amarelo
# 0   João    121212    BRANCO
# 1   João    343434     PRATA
# 2  Pedro    565656     PRATA
# 3   Caio    787878  VERMELHO

# %% [markdown]
# ### Cenário 2
#
# Importaremos uma nova tabela chamada tabela_4, idêntica à tabela_3, porém com uma coluna a mais, a coluna ‘Animais’ :

# %%
tabela_4 = pd.read_csv('tabela4.csv')
tabela_4
# Out:
#     nome  telefone  carros   animais
# 0   João    121212  BRANCO  cachorro
# 1   João    343434   PRATA      gato
# 2  Pedro    565656   PRATA  cachorro

# %%
t = pd.concat([tabela_1, tabela_4],ignore_index=True)
t
# Out:
#     nome  telefone   carros   animais
# 0   João    121212     azul       NaN
# 1   João    343434    preto       NaN
# 2  Pedro    565656    verde       NaN
# 3   Caio    787878  amarelo       NaN
# 4   João    121212   BRANCO  cachorro
# 5   João    343434    PRATA      gato
# 6  Pedro    565656    PRATA  cachorro

# %% [markdown]
# Como podemos ver, as linhas que vieram da tabela_1 receberam ‘NaN’ na coluna ‘Animais’. Previsivelmente, afinal essa coluna só existe na tabela_4.
#
# Aqui, cada linha isolada não faz sentido. Mas o usuário pode filtrar a tabela para obter a informação que deseja.
#
# O código abaixo, por exemplo, nos retorna todos ‘Animais’ relacionados a ‘Nome’ igual a ‘João’, excluindo aqueles valores que aparecem como NaN:

# %%
t[(t['nome'] == 'João') & (t['animais'].notna())]['animais']
# Out:
# 4    cachorro
# 5        gato
# Name: animais, dtype: object

# %% [markdown]
# Para ajustar os índices, basta incluir o parâmetro `ignore_index`:

# %%
# exemplo

# %% [markdown]
# Para concatenar horizontalmente, basta incluir o parâmetro `axis=1`:

# %%
# exemplo

# %% [markdown]
# ## Mesclando Dados

# %% [markdown]
# Caso queiramos a interseção exata entre as tabelas: `how = 'inner'`. Obtivemos a interseção entre as duas tabelas. Somente os valores na coluna “Nome” que existem em ambas tabelas aparecem no nosso resultado.

# %%
inner = pd.merge(tabela_1, tabela_2, how='inner', on='nome')
inner
# Out:
#    nome  telefone   carros  irmãos
# 0  João    121212     azul       1
# 1  João    343434    preto       1
# 2  Caio    787878  amarelo       2

# %% [markdown]
# Caso queiramos todas as informações, de ambas tabelas, fazemos um merge `how = 'outer'`. Perceba que "Pedro" não possui dados para “Irmãos”. E “Marcelo” e “Thiago” não possuem dados para “Telefone” e “Carros”. Volte nas tabelas 1 e 2 veja que esse é exatamente o resultado esperado se quisermos todas as informações.

# %%
outer = pd.merge(tabela_1, tabela_2, how='outer', on='nome')
outer
# Out:
#       nome  telefone   carros  irmãos
# 0     Caio  787878.0  amarelo     2.0
# 1     João  121212.0     azul     1.0
# 2     João  343434.0    preto     1.0
# 3  Marcelo       NaN      NaN     3.0
# 4    Pedro  565656.0    verde     NaN
# 5   Thiago       NaN      NaN     2.0

# %% [markdown]
# Um merge “left” ou “right” depende de qual tabela você deixa na direita ou esquerda. Para o seguinte cenário faremos um merge do tipo “left”. Mas o mesmo resultado pode ser obtido com um merge “right” trocando a posição das tabelas no método “merge”.

# %%
left = pd.merge(tabela_1, tabela_2, how='left', on='nome')
left
# Out:
#     nome  telefone   carros  irmãos
# 0   João    121212     azul     1.0
# 1   João    343434    preto     1.0
# 2  Pedro    565656    verde     NaN
# 3   Caio    787878  amarelo     2.0

# %%
rigth = pd.merge(tabela_2, tabela_1, how='rigth', on='nome')
rigth
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 rigth = pd.merge(tabela_2, tabela_1, how='rigth', on='nome')
#       2 rigth
#
# File c:\Users\kau7a\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\kau7a\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 886 join_index, left_indexer, right_indexer = self._get_join_info()
#     888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#
# File c:\Users\kau7a\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1151, in _MergeOperation._get_join_info(self)
#    1147     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1148         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1149     )
#    1150 else:
# -> 1151     (left_indexer, right_indexer) = self._get_join_indexers()
#    1153     if self.right_index:
#    1154         if len(self.left) > 0:
#
# File c:\Users\kau7a\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1125, in _MergeOperation._get_join_indexers(self)
#    1123 # make mypy happy
#    1124 assert self.how != "asof"
# -> 1125 return get_join_indexers(
#    1126     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1127 )
#
# File c:\Users\kau7a\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1759, in get_join_indexers(left_keys, right_keys, sort, how)
#    1757     _, lidx, ridx = left.join(right, how=how, return_indexers=True, sort=sort)
#    1758 else:
# -> 1759     lidx, ridx = get_join_indexers_non_unique(
#    1760         left._values, right._values, sort, how
#    1761     )
#    1763 if lidx is not None and is_range_indexer(lidx, len(left)):
#    1764     lidx = None
#
# File c:\Users\kau7a\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1802, in get_join_indexers_non_unique(left, right, sort, how)
#    1800 elif how == "outer":
#    1801     lidx, ridx = libjoin.full_outer_join(lkey, rkey, count)
# -> 1802 return lidx, ridx
#
# UnboundLocalError: cannot access local variable 'lidx' where it is not associated with a value

# %% [markdown]
# ### Cenários para merge left
#
# #### Cenário 1
#
# Suponhamos que para a sua tarefa você deva manter os dados da tabela_1 e ir acrescentando colunas conforme mais dados sobre ‘João’, ‘Pedro’ e ‘Caio’ apareçam. Em outras palavras, somente ‘Nomes’ que existam na tabela_1 serão trazidos da tabela_2. Neste exemplo deixaremos a tabela_1 à esquerda e faremos um merge ‘left’:

# %%
n = pd.merge(tabela_1, tabela_2, how='left', on='nome')
n
# Out:
#     nome  telefone   carros  irmãos
# 0   João    121212     azul     1.0
# 1   João    343434    preto     1.0
# 2  Pedro    565656    verde     NaN
# 3   Caio    787878  amarelo     2.0

# %% [markdown]
# #### Cenário 2
#
# Neste cenário uniremos a tabela_1 à tabela_3. Perceba que a nova tabela, tabela_3, é igual a tabela_1 mas com valores novos para a coluna ‘Carros’.
#
# O que você acha que vai acontecer se tentarmos unir tabela_1 e tabela_3? Com qual valor para ‘Carros’ devemos ficar ao efetuarmos o seguinte merge?

# %%
n = pd.merge(tabela_1, tabela_3, how='left', on='nome')
n
# Out:
#     nome  telefone_x carros_x  telefone_y  carros_y
# 0   João      121212     azul      121212    BRANCO
# 1   João      121212     azul      343434     PRATA
# 2   João      343434    preto      121212    BRANCO
# 3   João      343434    preto      343434     PRATA
# 4  Pedro      565656    verde      565656     PRATA
# 5   Caio      787878  amarelo      787878  VERMELHO

# %% [markdown]
# A nossa chave para o merge sendo ‘nome’, todas outras colunas iguais entre as tabelas são separadas em _x e _y, onde:
#
# _x Corresponde aos valores que existiam na tabela da esquerda (tabela_1).
# _y Corresponde aos valores que existiam na tabela da direita (tabela_3).
#
# Esses sufixos podem ser alterados.

# %%
n = pd.merge(tabela_1, tabela_3, how='left', on='nome').rename(columns={'carros_x': 'carro antigo', 'telefone_x': 'telefone antigo', 'carros_y': 'carro novo', 'telefone_y': 'telefone novo'})
n
# Out:
#     nome  telefone antigo carro antigo  telefone novo carro novo
# 0   João           121212         azul         121212     BRANCO
# 1   João           121212         azul         343434      PRATA
# 2   João           343434        preto         121212     BRANCO
# 3   João           343434        preto         343434      PRATA
# 4  Pedro           565656        verde         565656      PRATA
# 5   Caio           787878      amarelo         787878   VERMELHO
